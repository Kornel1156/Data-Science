# %% [markdown]
# <a href="https://colab.research.google.com/github/Kornel1156/Data-Science/blob/main/0_Konfiguracja/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello colab");
# Out:
# hello colab

# %% [markdown]
# ### OPCJA + tekst odbywa sie w jezyku znaczników MarkDown ,
# JAK UZYJEMY '###' TO STWORZYMY NAGŁÓWEK PO LEWEJ STRONIE
